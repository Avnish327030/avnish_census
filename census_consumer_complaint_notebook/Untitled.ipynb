# %%
import os

# %%
os.getcwd()
# Out:
# '/home/avnish/projects/avnish_census'

# %%
work_dir="/home/avnish/projects/avnish_census/"
os.chdir(work_dir)

# %%
work_dir
# Out:
# '/home/avnish/projects/avnish_census/'

# %%
from census_consumer_complaint_component.component import get_census_consumer_complaint_pipeline_component

# %%
pipeline_component = get_census_consumer_complaint_pipeline_component()

# %%
from census_consumer_complaint_orchestrator.interactive_context_runner import CensusConsumerInteractiveContext

# %%
interactive_context = CensusConsumerInteractiveContext().get_interactive_context()

# %%
interactive_context.run(pipeline_component[0])
# Out:
# ...
# Extracting file in  /home/avnish/projects/avnish_census/zip_to_csv
# <filter object at 0x7f623bdbc198> /home/avnish/projects/avnish_census/zip_to_csv
# 1000
#  2022-03-12 04:06:09.111153
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: RemoteZipCsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 14
#         uri: "/home/avnish/projects/avnish_census/census_consumer_complaint_data/census_consumer_complaint/artifact/RemoteZipCsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
# ...

# %%
interactive_context.run(pipeline_component[1])
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.

# %%
interactive_context.show(pipeline_component[1].outputs['statistics'])

# %%
from tfx.components import ImportExampleGen

# %%
i=ImportExampleGen(input_base=os.path.join("zip_to_csv"))

# %%
interactive_context.run(i)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: ImportExampleGen
#     execution_id: 2
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 2
#         type_id: 14
#         uri: "/home/avnish/projects/avnish_census/census_consumer_complaint_data/census_consumer_complaint/artifact/ImportExampleGen/examples/2"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
# ...

# %%
from tfx.components import StatisticsGen

# %%
sg = StatisticsGen(examples=pipeline_component[0].outputs['examples'])

# %%
interactive_context.run(sg)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 11
#     outputs:
#         statistics: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 11
#         type_id: 16
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/StatisticsGen/statistics/11"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "statistics"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "StatisticsGen"
#           }
#         }
#         custom_properties {
# ...

# %%
interactive_context.show(sg.outputs['statistics'])
# Out:
# <b>Artifact at /home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/StatisticsGen/statistics/11</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv("zip_to_csv/complaints.csv",chunksize=1000)

# %%
next(df).columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
columns
