# %%
from census_consumer_complaint_custom_component.example_gen import RemoteZipCsvExampleGen

# %%
uri="https://raw.githubusercontent.com/Avnish327030/ml_dataset/main/data.csv.zip"

# %%
import os

# %%
r=RemoteZipCsvExampleGen(zip_file_uri=uri,input_base=os.path.join("avnish"))

# %%
from census_consumer_complaint_orchestrator.interactive_context_runner import CensusConsumerInteractiveContext

# %%
c=CensusConsumerInteractiveContext().get_interactive_context()

# %%
c.run(r)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: RemoteZipCsvExampleGen
#     execution_id: 16
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 16
#         type_id: 14
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/RemoteZipCsvExampleGen/examples/16"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
# ...
