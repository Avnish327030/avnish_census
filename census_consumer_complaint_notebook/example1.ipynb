# %%
from census_consumer_complaint_custom_component.custom_component import ZipCsvExtractorGen

# %%
import os

# %%
# !pwd
# Out:
# /home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_notebook

# %%
work_dir="/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data"

# %%
os.chdir(work_dir)

# %%
os.getcwd()
# Out:
# '/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data'

# %%
URI = r"https://files.consumerfinance.gov/ccdb/complaints.csv.zip"
zip_csv_extractor_gen = ZipCsvExtractorGen(input_base=URI,name="zipextractor")

# %%
from census_consumer_complaint_pipeline_config.configuration import CensusConsumerInteractiveContext

# %%
census_consumer_interactive_context = CensusConsumerInteractiveContext()

# %%
interactive_context = census_consumer_interactive_context.get_interactive_context()

# %%
interactive_context.run(zip_csv_extractor_gen)
# Out:
# ExecutionResult(
#     component_id: ZipCsvExtractorGen
#     execution_id: 5
#     outputs:
#         csv: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 14
#         uri: "census_consumer_pipeline/ZipCsvExtractorGen/csv/1"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "csv"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "ZipCsvExtractorGen"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         create_time_since_epoch: 1646824168828
#         last_update_time_since_epoch: 1646824198378
# ...

# %%
zip_csv_extractor_gen.outputs['csv'].get()[0].uri
# Out:
# 'census_consumer_pipeline/ZipCsvExtractorGen/csv/1'

# %%
from tfx.components import CsvExampleGen

# %%
csv_example_gen = CsvExampleGen(zip_csv_extractor_gen.outputs['csv'].get()[0].uri)

# %%
interactive_context.run(csv_example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
